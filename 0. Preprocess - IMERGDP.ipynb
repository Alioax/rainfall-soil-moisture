# %%
import pandas as pd
import numpy as np
import os
import glob
import h5py
from datetime import datetime

import matplotlib.pyplot as plt
import matplotlib as mpl

mpl.rcParams['figure.dpi']= 800
plt.rcParams["font.family"] = "Times New Roman"
mpl.rcParams['axes.prop_cycle'] = mpl.cycler(color=["#FF5F05", "#13294B", "#009FD4", "#FCB316", "#006230", "#007E8E", "#5C0E41", "#7D3E13"])

# %%
raw_data_dir = os.path.join("data\\processed\\IMERGDP", "Granules")
all_paths = glob.glob(os.path.join(raw_data_dir, "**", "*"), recursive=True)
all_files = [f for f in all_paths if (os.path.isfile(f)) & (f.endswith(".csv"))]

# %%
df = pd.concat([pd.read_csv(file) for file in all_files])
df = df.drop('valid_count', axis=1)

# %%
df.to_csv('./data/processed/IMERGDP/IMERGDP_summary.csv', index=False)

# %%
df["date"] = pd.to_datetime(df["date"])

# %%
df = df.set_index('date')
df = df.sort_index()

# %%
df.loc[:, 'precipitation'].plot()
# Out:
# <Axes: xlabel='date'>

# %%
print("Index type:", type(df.index))
print("\nFirst few dates in index:")
print(df.index[:5])
# Out:
# Index type: <class 'pandas.core.indexes.datetimes.DatetimeIndex'>
#
# First few dates in index:
# DatetimeIndex(['2022-01-01', '2022-01-02', '2022-01-03', '2022-01-04',
#                '2022-01-05'],
#               dtype='datetime64[ns]', name='date', freq=None)
